# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_n = [0, -2, -2, -2]
y_n = [2, 2, 0, -2]

x_a = [0, 2, 2, 2]
y_a = [-2, 0, -2, 2]

x1=2
y1=3

# %%
plt.plot(x_n,y_n,  linestyle="none", marker="o", color="orange", label="Naranja")
plt.plot(x_a,y_a,  linestyle="none", marker="o", color="blue", label="Azul")
plt.legend(loc=10)
plt.grid()
plt.show()

# %%
x = [3, -3]
y = [4.5, -4.5]

# %%
plt.plot(x_n,y_n,  linestyle="none", marker="o", color="orange", label="Naranja")
plt.plot(x_a,y_a,  linestyle="none", marker="o", color="blue", label="Azul")
plt.plot(x, y, linestyle="solid", marker="p", color="Steelblue")
plt.legend(loc=2)
plt.grid()
plt.show()

# %%
m = (y[1] - y[0]) / (x[1] - x[0])

# %%
def funcion_w(m):
    return (m*1)

# %%
b = m*(-x1)+y1
w = [funcion_w(m),-1]

# %%
print("Resultado recta")
print("Entradas= 1=",x_n,y_n, "2=",x_a,y_a)
print("Pendiente =",m)
print("Punto de corte con Y (bias)=",b)
print("Peso =",w[0],w[1])
# Out:
# Resultado recta
# Entradas= 1= [0, -2, -2, -2] [2, 2, 0, -2] 2= [0, 2, 2, 2] [-2, 0, -2, 2]
# Pendiente = 1.5
# Punto de corte con Y (bias)= 0.0
# Peso = 1.5 -1

# %%
x_n = [0, -2, -2, 2, 2]
y_n = [2, 2, 0, 0, 2]

x_a = [ -2, 2, 0]
y_a = [ -2, -2 , -2]

x = [-3, 0, 3]
y = [-1, -1, -1]

x1=2
y1=-1
plt.plot(x_n,y_n,  linestyle="none", marker="o", color="orange", label="Naranja")
plt.plot(x_a,y_a,  linestyle="none", marker="o", color="blue", label="Azul")
plt.plot(x, y, linestyle="solid", marker="p", color="Steelblue")
plt.legend(loc=2)
plt.grid()
plt.show()

# %%
m = (y[1] - y[0]) / (x[1] - x[0])
def funcion_w(m):
    return (m*1)
b = m*(-x1)+y1
w = [funcion_w(m),1]

# %%
print("Resultado recta")
print("Entradas= 1=",x_n,y_n, "2=",x_a,y_a)
print("Pendiente =",m)
print("Punto de corte con Y (bias)=",b)
print("Peso =",w[0],w[1])
# Out:
# Resultado recta
# Entradas= 1= [0, -2, -2, 2, 2] [2, 2, 0, 0, 2] 2= [-2, 2, 0] [-2, -2, -2]
# Pendiente = 0.0
# Punto de corte con Y (bias)= -1.0
# Peso = 0.0 1

# %%
x_n = [-2]
y_n = [2]

x_a = [ -2, 2, 0, 0, -2, 2, 2]
y_a = [ -2, -2 , -2, 2, 0, 0, 2]

x = [1, -4]
y = [4, -1]

x1=1
y1=4
plt.plot(x_n,y_n,  linestyle="none", marker="o", color="orange", label="Naranja")
plt.plot(x_a,y_a,  linestyle="none", marker="o", color="blue", label="Azul")
plt.plot(x, y, linestyle="solid", marker="p", color="Steelblue")
plt.legend(loc=2)
plt.grid()
plt.show()

# %%
m = (y[1] - y[0]) / (x[1] - x[0])
def funcion_w(m):
    return (m*1)
b = m*(-x1)+y1
w = [funcion_w(m),-1]

# %%
print("Resultado recta")
print("Entradas= 1=",x_n,y_n, "2=",x_a,y_a)
print("Pendiente =",m)
print("Punto de corte con Y (bias)=",b)
print("Peso =",w[0],w[1])
# Out:
# Resultado recta
# Entradas= 1= [-2] [2] 2= [-2, 2, 0, 0, -2, 2, 2] [-2, -2, -2, 2, 0, 0, 2]
# Pendiente = 1.0
# Punto de corte con Y (bias)= 3.0
# Peso = 1.0 -1
